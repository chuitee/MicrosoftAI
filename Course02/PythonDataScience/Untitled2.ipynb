# %%
import numpy as np
z = np.array([[5, 9, 8], 
              [9, 0, 6]])
print(z[0:, 1:])
# Out:
# [[9 8]
#  [0 6]]

# %%
x = ["D", "B", "A", "E", "F", "C"]
print(x("A"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-e38e31f400ce> in <module>
#       1 x = ["D", "B", "A", "E", "F", "C"]
# ----> 2 print(x("A"))
#
# TypeError: 'list' object is not callable

# %%
x = [1, 2, 3, 4]
y = x
y[1:3] = [5, 6]
print(x)
# Out:
# [1, 5, 6, 4]

# %%
import numpy as np
np_2d = np.array([[4, 5, 6], 
                  [11, 12, 13]])
print(np_2d[1:, 2:])
# Out:
# [[13]]

# %%
import pandas as pd
marketing = pd.read_csv("https://goo.gl/6A6Qe2")
print(marketing.loc['b'
, 
'b'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [b] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-784d1bc81a3b> in <module>
#       1 import pandas as pd
#       2 marketing = pd.read_csv("https://goo.gl/6A6Qe2")
# ----> 3 print(marketing.loc['b'
# ...

# %%
import pandas as pd
dataset = "https://goo.gl/0ZTtdk"
data_frame = pd.read_csv(dataset)
print(data_frame)
# Out:
#   Product Store  Units  Cost
# 0       A     X     10    20
# 1       A     Y     12    22
# 2       A     Z     10    25

# %%
a = 7
b = [0, 1]
c = 4
print(b+str(a)+str(c))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-945b6cb7b799> in <module>
#       2 b = [0, 1]
#       3 c = 4
# ----> 4 print(b+str(a)+str(c))
#
# TypeError: can only concatenate list (not "str") to list

# %%
x = ["e", "y", "w", "j", "u", "h"]
print(x[-3:])
# Out:
# ['j', 'u', 'h']

# %%
import numpy as np
np_2d = np.array([[4, 7, 8], 
                  [17, 13, 4]])
print(np_2d[0][2])
# Out:
# 8

# %%
a = True
b = "6"
c = 5
d = 10.25
print(type(b))
# Out:
# <class 'str'>

# %%
import pandas as pd
classes = pd.read_csv("https://goo.gl/JvBiH4")
classes['Course'] = ["Math", "Math", "Science"]
print(classes)
# Out:
#    ID  Enrolled   Course
# 0   1        20     Math
# 1   2        18     Math
# 2   3        22  Science

# %%
# Find the mean of the first column of costs
import numpy as np
costs = np.column_stack(([1, 1, 2, 2, 3, 3, 2, 1], 
                         [4, 4, 4, 7, 7, 7, 4, 7]))
mean_costs = np.mean(costs[0:0])
print(mean_costs)
# Out:
# nan

# %%
x = [4, 8, 12, 16, 20, 24]
print(x[1] + x[5])
# Out:
# 32

# %%
x = [1, 2, 3, 4, 5, 6]
print(x[1:4])
# Out:
# [2, 3, 4]

# %%
x = True
if not x:
    print("First attempt")
elif x % 2 == 0:
    print("Second attempt")
else:
    print("Final attempt")
# Out:
# Final attempt

# %%
import numpy as np
x = np.array([1, 2, False, True, 3])
print(x)
# Out:
# [1 2 0 1 3]

# %%
import numpy as np
x = np.array([6, 2, 4])
y = np.array([True, False, True])
print(x * y)
# Out:
# [6 0 4]

# %%
from numpy import array

# %%
x = ["E", 7, "G", 20, 2, "M"]
del(x[4])
print(x)
# Out:
# ['E', 7, 'G', 20, 'M']

# %%
import numpy as np
store = np.array(["A", "A", "B", "C", "C", "C", "B"])
cost = np.array([20, 24, 21, 23, 29, 25, 27])
select_cost = cost[store subset cost]
print(select_cost)
# Out:
#   File "<ipython-input-32-d368f60b450d>", line 4
#     select_cost = cost[store subset cost]
#                                   ^
# SyntaxError: invalid syntax

# %%
import numpy as np
x = np.array([[6, 4, 2], [2, 1, 1]])
y = np.array([[6, 2, 4], [2, 2, 1]])
print(x + y)
# Out:
# [[12  6  6]
#  [ 4  3  2]]

# %%
import numpy as np
x = np.array([[6, 4, 2], [2, 1, 1]])
y = np.array([[6, 2, 4], [2, 2, 1]])
print(x * y)
# Out:
# [[36  8  8]
#  [ 4  2  1]]

# %%
import numpy as np
x = np.array([[6, 4, 2], [2, 1, 1]])
y = np.array([[6, 2, 4], [2, 2, 1]])
print(x / y)
# Out:
# [[1.  2.  0.5]
#  [1.  0.5 1. ]]

# %%
x = 5
y = -2
z = 19
print('['+ str(x) + ',' + str(y) + ',' + str(z) + ']')
# Out:
# [5,-2,19]

# %%
import math

vMag = math.sqrt(3**2 + 5**2)
print (vMag)
# Out:
# 5.830951894845301

# %%
import numpy as np

v = np.array([2,5])
s = np.array([4,3])
d = v @ s
print (d)
# Out:
# 23

# %%
import numpy as np

p = np.array([4,1,6])
q = np.array([2,3,5])
r = np.cross(p,q)
print (r)
# Out:
# [-13  -8  10]

# %%
import numpy as np

B = np.array([[5,3],
              [6,4]])

print(np.linalg.inv(B))
# Out:
# [[ 2.  -1.5]
#  [-3.   2.5]]

# %%
import pandas as pd


df = pd.DataFrame({'Salary':[184,180,181,184,182,181,182,182,183,182,181,182,182,180,183,181,184,183,182,182,183,182,183,181,180,181,183]})

print (df['Salary'].std())
# Out:
# 1.1766968108291043

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

df = pd.DataFrame({'Salary':[184,180,181,184,182,181,182,182,183,182,181,182,182,180,183,181,184,183,182,182,183,182,183,181,180,181,183]})

salary = df['Salary']
density = stats.gaussian_kde(salary)
n, x, _ = plt.hist(salary, histtype='step', normed=True, bins=25)  
plt.plot(x, density(x)*5)
plt.axvline(salary.mean(), color='magenta', linestyle='dashed', linewidth=2)
plt.axvline(salary.median(), color='green', linestyle='dashed', linewidth=2)
plt.show()

# %%
# %matplotlib inline
from scipy.stats import binom
from matplotlib import pyplot as plt
import numpy as np

n = 5
p = 0.4
k = 3
x = np.array(range(0, n+1))

prob = np.array([binom.pmf(k, n, p) for k in x])

# Set up the graph
plt.xlabel('x')
plt.ylabel('Probability')
plt.bar(x, prob)
plt.show()
